# %%
import pandas as pd

data = pd.read_csv('/Users/nabraja/Sapient/Projects/Lloyds/MIP/DS/Codebase/mip-python-training/data/flights.csv')

# %%
data.shape
# Out:
# (499999, 31)

# %%
data.head(100)
# Out:
#     YEAR  MONTH  DAY AIRLINE  FLIGHT_NUMBER TAIL_NUMBER ORIGIN_AIRPORT  \
# 0   2015      1    1      AS             98      N407AS            ANC
# 1   2015      1    1      AA           2336      N3KUAA            LAX
# 2   2015      1    1      US            840      N171US            SFO
# 3   2015      1    1      AA            258      N3HYAA            LAX
# 4   2015      1    1      AS            135      N527AS            SEA
# 5   2015      1    1      DL            806      N3730B            SFO
# 6   2015      1    1      NK            612      N635NK            LAS
# 7   2015      1    1      US           2013      N584UW            LAX
# 8   2015      1    1      AA           1112      N3LAAA            SFO
# 9   2015      1    1      DL           1173      N826DN            LAS
# 10  2015      1    1      DL           2336      N958DN            DEN
# 11  2015      1    1      AA           1674      N853AA            LAS
# ...

# %%
data.dtypes
# Out:
# YEAR                     int64
# MONTH                    int64
# DAY                      int64
# DAY_OF_WEEK              int64
# AIRLINE                 object
# FLIGHT_NUMBER            int64
# TAIL_NUMBER             object
# ORIGIN_AIRPORT          object
# DESTINATION_AIRPORT     object
# SCHEDULED_DEPARTURE      int64
# DEPARTURE_TIME         float64
# DEPARTURE_DELAY        float64
# TAXI_OUT               float64
# WHEELS_OFF             float64
# SCHEDULED_TIME         float64
# ELAPSED_TIME           float64
# AIR_TIME               float64
# DISTANCE                 int64
# WHEELS_ON              float64
# TAXI_IN                float64
# SCHEDULED_ARRIVAL        int64
# ARRIVAL_TIME           float64
# ARRIVAL_DELAY          float64
# DIVERTED                 int64
# CANCELLED                int64
# CANCELLATION_REASON     object
# AIR_SYSTEM_DELAY       float64
# SECURITY_DELAY         float64
# AIRLINE_DELAY          float64
# LATE_AIRCRAFT_DELAY    float64
# ...

# %%
data = data.drop("DAY_OF_WEEK", axis=1)

# %%
data = data.rename(columns={"WHEELS_OFF": "HAS_WHEELS"})

# %%
data.dtypes
# Out:
# YEAR                     int64
# MONTH                    int64
# DAY                      int64
# AIRLINE                 object
# FLIGHT_NUMBER            int64
# TAIL_NUMBER             object
# ORIGIN_AIRPORT          object
# DESTINATION_AIRPORT     object
# SCHEDULED_DEPARTURE      int64
# DEPARTURE_TIME         float64
# DEPARTURE_DELAY        float64
# TAXI_OUT               float64
# HAS_WHEELS             float64
# SCHEDULED_TIME         float64
# ELAPSED_TIME           float64
# AIR_TIME               float64
# DISTANCE                 int64
# WHEELS_ON              float64
# TAXI_IN                float64
# SCHEDULED_ARRIVAL        int64
# ARRIVAL_TIME           float64
# ARRIVAL_DELAY          float64
# DIVERTED                 int64
# CANCELLED                int64
# CANCELLATION_REASON     object
# AIR_SYSTEM_DELAY       float64
# SECURITY_DELAY         float64
# AIRLINE_DELAY          float64
# LATE_AIRCRAFT_DELAY    float64
# WEATHER_DELAY          float64
# ...

# %%
import numpy as np

chunks = np.array_split(data, 4)

# %%
len(chunks)
# Out:
# 4

# %%
data.describe()
# Out:
#            YEAR          MONTH            DAY  FLIGHT_NUMBER  \
# count  499999.0  499999.000000  499999.000000  499999.000000
# mean     2015.0       1.060062      14.995448    2263.471527
# std         0.0       0.237602       9.320105    1803.531063
# min      2015.0       1.000000       1.000000       1.000000
# 25%      2015.0       1.000000       7.000000     759.000000
# 50%      2015.0       1.000000      15.000000    1732.000000
# 75%      2015.0       1.000000      23.000000    3484.000000
# max      2015.0       2.000000      31.000000    9793.000000
#
#        SCHEDULED_DEPARTURE  DEPARTURE_TIME  DEPARTURE_DELAY       TAXI_OUT  \
# count        499999.000000   483583.000000    483583.000000  483295.000000
# mean           1323.041714     1332.958619        10.122676      16.487882
# std             468.226070      479.872733        37.720260       9.671999
# min               5.000000        1.000000       -48.000000       1.000000
# ...

# %%
std = data["DEPARTURE_DELAY"].std()

# %%
third_std = 3 * std
print(third_std)
# Out:
# 113.16078076479788

# %%
data[((data["DEPARTURE_DELAY"] - data["DEPARTURE_DELAY"].mean())/data["DEPARTURE_DELAY"].std()).abs() < 3]
data["DEPARTURE_DELAY"].head(10)
# Out:
# 0   -11.0
# 1    -8.0
# 2    -2.0
# 3    -5.0
# 4    -1.0
# 5    -5.0
# 6    -6.0
# 7    14.0
# 8   -11.0
# 9     3.0
# Name: DEPARTURE_DELAY, dtype: float64

# %%
data["DEPARTURE_DELAY"].std()
# Out:
# 37.720260254932626

# %%
delay_airline = data[['AIRLINE', 'DEPARTURE_DELAY']].groupby('AIRLINE').mean()
print(delay_airline)
# Out:
#          DEPARTURE_DELAY
# AIRLINE
# AA             10.643729
# AS              3.430815
# B6             10.774558
# DL              6.775430
# EV             10.043026
# F9             19.664576
# HA              1.109583
# MQ             16.141276
# NK             14.016792
# OO             12.458124
# UA             14.169355
# US              6.108520
# VX              6.815032
# WN              9.631559

# %%
morning_flights = data[data["DEPARTURE_TIME"] < 1200].groupby('AIRLINE')
